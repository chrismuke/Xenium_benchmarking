# %%
import spatialdata as sd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_420455/920971077.py in <module>
# ----> 1 import spatialdata as sd
#
# ModuleNotFoundError: No module named 'spatialdata'
